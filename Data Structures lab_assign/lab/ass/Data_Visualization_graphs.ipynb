# %% [markdown]
# ## Data Visualization using Matplotlib (Part1)
#
# ### Data Visualization
# 1. Graphical representation of information and data
# 2. Graph, Chart, and Map make it easier to understand the patterns in data
# 3. Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# 4. Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# ##### Self Learning Resource
# 1. Matplotlib: <a href="https://matplotlib.org/3.3.1/gallery/index.html"> Examples</a> | <a href="https://matplotlib.org/3.3.1/gallery/index.html"> Tutorials</a>
# 2. Seaborn: <a href="https://seaborn.pydata.org/examples/index.html"> Examples</a> | <a href="https://seaborn.pydata.org/tutorial.html"> Tutorials</a>
# 3. Data visualization using matplotlib, seaborn, plotly - <a href="https://www.kaggle.com/abhishekvaid19968/data-visualization-using-matplotlib-seaborn-plotly"> Click Here </a>

# %% [markdown]
# ##  <span style='color:Red'>Import matplotlib</span>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## <span style='color:Blue'>1. Line plot</span>

# %% [markdown]
# ### 1.1 Plot a line

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [i **2 for i in x ]

plt.plot(x, y)

plt.show()

# %% [markdown]
# ##### To save plot in a file

# %%
#As the name suggests savefig() method is used to save the figure created after plotting data. 
#The figure created can be saved to our local machines by using this method.
plt.savefig("graph.jpeg")

# %% [markdown]
# ### 1.2 Plot a line with details

# %%
x = [5, 2, 7]
y = [2, 16, 4]
#3 data points ex (5,2)

plt.plot(x, y)

plt.title('This is Title')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# ### 1.3 Plot multiple lines

# %%
x  = [1, 2, 3, 4, 5]
y1 = [50, 40, 70, 80, 20]
y2 = [80, 20, 20, 50, 60]
y3 = [70, 20, 60, 40, 60]
y4 = [80, 20, 20, 50, 60]

plt.plot(x, y1, 'g', label='Enfield', linewidth=2)
plt.plot(x, y2, 'c', label='Honda', linewidth=1)
plt.plot(x, y3, 'k', label='Yahama', linewidth=3)
plt.plot(x, y4, 'r', label='KTM', linewidth=2)

plt.title('Bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')

plt.legend()           #Adding Legends

plt.show()

# %% [markdown]
# ## <span style='color:Blue'>2. Bar plot</span>

# %% [markdown]
# ### 2.1 Plot a bar chart

# %%
y = [50, 60, 30, 70, 20]
x = ["A", "B", "C", "D", "E"]

plt.bar(x, y, color = "red")

plt.show()

# %% [markdown]
# ### 2.2 Multiple bar plot

# %% [markdown]
# #### Example 1

# %%
x1 = [0.25, 1.25, 2.25, 3.25, 4.25]
y1 = [50, 40, 70, 80, 20]

plt.bar(x1, y1, label="BMW", color='r')

x2 = [.75, 1.75, 2.75, 3.75, 4.75]
y2 = [80, 20, 20, 50, 60]
plt.bar(x2, y2, label="Audi", color='y')

plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Information')

plt.legend()
plt.show()

# %% [markdown]
# #### Example 2

# %%
x1 = [0.25, 1.25, 2.25, 3.25, 4.25]
y1 = [50, 40, 70, 80, 20]
plt.bar(x1, y1, label="Enfield", width=0.25)

x2 = [0.26, 1.25, 2.25, 3.25, 4.25]
y2 = [80, 20, 20, 50, 60]
plt.bar(x2, y2, label="Honda", color='r', width=.25)

x3 = [0.31, 1.5, 2.5, 3.5, 4.5]
y3 = [70, 20, 60, 40, 60]
plt.bar(x3, y3, label="Yamaha", color='y', width=.25)

x4 = [.75, 1.75, 2.75, 3.75, 4.75]
y4 = [80, 20, 20, 50, 60]
plt.bar(x4, y4, label="KTM", color='g', width=.25)

plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')

plt.title('Bikes details in BAR PLOTTING')

plt.show()

# %% [markdown]
# ### 2.3 Horizontal Bar Plot (barh)

# %%
x = [5, 6, 3, 7, 2]
y = ["A", "B", "C", "D", "E"]

plt.barh(y,x,color ="orange")

plt.show()

# %% [markdown]
# ## <span style='color:Blue'>3. Scatter plot</span>

# %% [markdown]
# ### 3.1 Scatter plot

# %%
x = [5, 2, 9, 4, 7]     # x-axis values 
y = [10, 5, 8, 4, 2]         # Y-axis values 

plt.scatter(x, y)         # Function to plot scatter 

plt.show()               # function to show the plot

# %% [markdown]
# ### 3.2 Scatter plot with title, x-axis and y-axis

# %%
x = [35, 20, 29, 40, 57]     # x-axis values 
y = [100, 50, 80, 40, 200]         # Y-axis values 

plt.scatter(x, y)         # Function to plot scatter 

plt.xlabel('Salary * 1000')
plt.ylabel('Age)')
plt.title('Age Vs Salary')

plt.show()               # function to show the plot

# %% [markdown]
# ### 3.3 Multiple scatter plot

# %%
x1 = [1, 1.5, 2, 2.5, 3, 3.5, 3.6]
y1 = [7.5, 8, 8.5, 9, 9.5, 10, 10.5]

x2 = [8, 8.5, 9, 9.5, 10, 10.5, 11]
y2 = [3, 3.5, 3.7, 4, 4.5, 5, 5.2]

plt.scatter(x1, y1, label='High income low saving',  color='r')
plt.scatter(x2, y2, label='Low income high savings', color='b')

plt.xlabel('Saving*100')
plt.ylabel('Income*1000')
plt.title('Scatter Plot')

plt.legend()

plt.grid()
plt.show()

# %% [markdown]
# ## <span style='color:Blue'>4. Pie plot</span>

# %% [markdown]
# #### Example 1

# %%
grades = 'A', 'A-', 'B', 'B-', 'C', 'E'
gradeCount = [50, 60, 140, 160, 30, 20]

plt.pie(gradeCount, labels=grades, autopct='%1.1f%%')

plt.show()

print(type(grades)) #by default tuple banega varna say if grades list hogi..list ans aayega
# Out:
# <class 'list'>

# %% [markdown]
# #### Example 2

# %%
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.2, 0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode = explode, labels=labels, colors=colors,
        autopct='%1.1f%%',shadow=True)

plt.axis('equal')
plt.show()

# %% [markdown]
# #### Example 3

# %%
share = [3,4,2,1]
bikes = ['Enfield','Honda','Yahama','KTM']

plt.pie(share, labels=bikes, shadow= True, explode=(0,0.1,0,0), 
        autopct='%1.1f%%')

plt.title('Bike Shares')

plt.show()

# %% [markdown]
# ## <span style='color:Blue'>5. Matplotlib plots on NBA dataset</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('nba16.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16656/1711712550.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df = pd.read_csv('nba16.csv')
#       5 df.head()
#
# D:\software downloads\python\colab\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# D:\software downloads\python\colab\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nba16.csv'

# %% [markdown]
# ### 5.1 Bar graph

# %%
x = df['Age']
y = df['Salary']

plt.xlabel('Age')                                   
plt.ylabel('Salary (in millions)')
plt.title('Salary Vs Age')

plt.bar(x, y, color = "purple")

plt.show()

# %% [markdown]
# ### 5.2 Horizontal bar graph

# %%
y = df['Age']
x = df['Salary']

plt.xlabel('Salary(millions)')                                   
plt.ylabel('Age')
plt.title('Age vs salary')

plt.barh(y, x color = "green")
#barh me y,x pass krte hai

plt.show()

# %% [markdown]
# ### 5.3 Scatter plot

# %%
x = df['Age']
y = df['Salary']

plt.xlabel('Age')                                   
plt.ylabel('Salary (in millions)')
plt.title('Salary Vs Age')

plt.scatter(x, y, marker = "*")

# marker {'o','+','x','^','*','_'}

plt.show()

# %% [markdown]
# ## <span style='color:Blue'>6. Plotting Mathematical Functions</span>
# ### 6.1 Plot sine curve
# #### Example 1

# %%
# Compute the x and y coordinates for points on a sine curve 
import math as m
import random as r

x = [ m.pi * i  for i in range(0, 10)]
y = [ m.sin(i) for i in x ]

plt.plot(x, y)
plt.title("sin(pi) wave form")

plt.show()

# %% [markdown]
# #### Example 2: Sine wave

# %%
import numpy as np

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 

plt.plot(x, y) 
plt.title("Sine wave form")

plt.show()

# %% [markdown]
# #### Example 3: Cos wave

# %%
import numpy as np

# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.cos(x) 

plt.plot(x, y) 
plt.title("Cos wave form")

plt.show()

# %% [markdown]
# ### 6.2 Subplot
# #### Example 1

# %%
import numpy as np

# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 

y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
plt.plot(x, y_cos,'g--') 
plt.plot(x, y_sin,'r--') 
plt.title('Sine and Cosine')  
   
plt.show()

# %% [markdown]
# #### Example 2

# %%
import numpy as np

x = np.arange(0, 5 * np.pi, 0.1) 

y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, and 
#     set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
plt.show()

# %% [markdown]
# ## <span style='color:Blue'>7. Box Plot</span>

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# loc means mean of he data
# std controls he standard deviation 
# size of the data
#print(data)
plt.boxplot(data)# ,vert=False), notch = True
plt.show()

#data

# %% [markdown]
# ## <span style='color:Blue'>8. Plot Time Series</span>

# %% [markdown]
# ##### Import libraries

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ##### Read Dataset

# %%
series = read_csv('data16.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
print(series.head())


#header=0: We must specify the header information at row 0.
#parse_dates=[0]: We give the function a hint that data in the first column contains dates that need to be parsed.
#This argument takes a list, so we provide it a list of one element, which is the index of the first column.
#index_col=0: We hint that the first column contains the index information for the time series.
#squeeze=True: We hint that we only have one data column and that we are interested in a Series and not a DataFrame.
# Out:
# Date
# 1981-01-01    20.7
# 1981-02-01    17.9
# 1981-03-01    18.8
# 1981-04-01    14.6
# 1981-05-01    15.8
# Name: Temp, dtype: float64

# %% [markdown]
# ##### Minimum Daily Temperature Line Plot

# %%
series.plot()
pyplot.show()

# %% [markdown]
# ##### Minimum Daily Temperature Dot Plot

# %%
series.plot(style='k*') 
#b for blue and k for black
pyplot.show()

# %% [markdown]
# ##### Minimum Daily Temperature Yearly Line Plots

# %%
from pandas import DataFrame
from pandas import Grouper
#groupBy me grouping krdenge say city ke basis pe group krdiya 
#toh all newyork vale ekathe hojaynge and ab newyrk is the key and uska pair will be poora datafrme corrspndng to new york
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False)
pyplot.show()
#10 subplots banaliye, one for each year starting with 1981

# %% [markdown]
# ##### Minimum Daily Temperature Histogram Plot

# %%
series.hist()
pyplot.show()
#x axis: temp value
# y axis: voh temp kitni baar attain hue hai in any of the day of the year

# %% [markdown]
# ##### Minimum Daily Temperature Density Plot

# %%
series.plot(kind='kde')#Kernel Density Estimate
pyplot.show()

# %% [markdown]
# ##### Minimum Daily Temperature Yearly Box and Whisker Plots

# %%
from pandas import DataFrame
from pandas import Grouper
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.boxplot()
pyplot.show()

# %% [markdown]
# ##### Minimum Daily Temperature Yearly Heat Map Plot

# %%
from pandas import Grouper
from matplotlib import pyplot
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years = years.T
pyplot.matshow(years, interpolation=None, aspect='auto') #used ot represent array as matrix
pyplot.show()
#matrix ki har value/cell ko ek unique color assign hoga
#larger value: yellow/red while smaller value: blue/green

# %% [markdown]
# ##### Minimum Daily Temperature Lag Plot

# %%
from pandas.plotting import lag_plot
#It plots the observation at time t on the x-axis and the lag1 observation (t-1) on the y-axis
lag_plot(series)
pyplot.show()
#previous obs: lag..current observtn (t): lag1
#if bottom left to top right jaata hai ye graph means pos
#corrltn hai in data
#top left to botm right: neg corltn
#jitna zyada data ek strght line me dikhega, utni zyada strng reltnp hogi
#agar grph me beech me gap hoga means no/weaker corltn

# %% [markdown]
# ##### Minimum Daily Temperature Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()
#Autocorrelation / self corltn(ACF) is a calculated value used to represent how similar 
#a value within a time series is to a previous value.
#dotted line ko jo blue line touch nahi kregi, vahi vali blue
#line is meanigfl fr us
#prpr sine wave shows strng simlrty in the dataset
