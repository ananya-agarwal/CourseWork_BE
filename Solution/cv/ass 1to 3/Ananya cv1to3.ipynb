# %% [markdown]
# # **Assignment for Computer vision**: **Face Detection With Deep Learning**

# %% [markdown]
# Face detection is a computer vision problem that involves finding faces in photos. Face detection can be performed using the classical feature-based cascade classifier using the OpenCV library. State-of-the-art face detection can be achieved using a Multi-task Cascade CNN via the MTCNN library.
#
# Face detection is a problem in computer vision of locating and localizing one or more faces in a photograph. Locating a face in a photograph refers to finding the coordinate of the face in the image, whereas localization refers to demarcating the extent of the face, often via a bounding box around the face.
#
# A general statement of the problem can be defined as follows: Given a still or video image, detect and localize an unknown number (if any) of faces. Detecting faces in a photograph is easily solved by humans, although has historically been challenging for computers given the dynamic nature of faces. For example, faces must be detected regardless of orientation or angle they are facing, light levels, clothing, accessories, hair color, facial hair, makeup, age, and so on.
#
# The human face is a dynamic object and has a high degree of variability in its appearance, which makes face detection a difficult problem in computer vision. Given a photograph, a face detection system will output zero or more bounding boxes that contain faces. Detected faces can then be provided as input to a subsequent system, such as a face recognition system.
#
# Face detection is a necessary first-step in face recognition systems, with the purpose of localizing and extracting the face region from the background.

# %% [markdown]
# A number of deep learning methods have been developed and demonstrated for face detection. One of the more popular approaches is called the “Multi-Task Cascaded Convolutional Neural Network,” or MTCNN for short, described by Kaipeng Zhang, et al. in the 2016 paper titled “Joint Face Detection and Alignment Using Multitask Cascaded Convolutional Networks.”
#
# https://arxiv.org/ftp/arxiv/papers/1604/1604.02878.pdf
#
# The MTCNN is popular because it achieved then state-of-the-art results on a range of benchmark datasets, and because it is capable of also recognizing other facial features such as eyes and mouth, called landmark detection.
#
# The network uses a cascade structure with three networks; first the image is rescaled to a range of different sizes (called an image pyramid), then the first model (Proposal Network or P-Net) proposes candidate facial regions, the second model (Refine Network or R-Net) filters the bounding boxes, and the third model (Output Network or O-Net) proposes facial landmarks.

# %% [markdown]
# The library can be installed via pip

# %%
# !pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: mtcnn in c:\users\dev\anaconda3\envs\gpu\lib\site-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\dev\anaconda3\envs\gpu\lib\site-packages (from mtcnn) (2.8.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\dev\anaconda3\envs\gpu\lib\site-packages (from mtcnn) (4.5.5.64)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dev\anaconda3\envs\gpu\lib\site-packages (from opencv-python>=4.1.0->mtcnn) (1.22.3)

# %%
conda install -c conda-forge mtcnn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install numpy --force-reinstall
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dev\anaconda3\envs\GPU
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1n             |       h2bbff1b_0         4.8 MB
#     ------------------------------------------------------------
#                                            Total:         4.8 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    intel::ca-certificates-2022.3.18-haa9~ --> pkgs/main::ca-certificates-2022.4.26-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                             intel --> pkgs/main
#   openssl                                             intel --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# Note: you may need to restart the kernel to use updated packages.
#
# openssl-1.1.1n       | 4.8 MB    |            |   0%
# openssl-1.1.1n       | 4.8 MB    |            |   0%
# openssl-1.1.1n       | 4.8 MB    | 6          |   6%
# openssl-1.1.1n       | 4.8 MB    | #3         |  14%
# openssl-1.1.1n       | 4.8 MB    | ##         |  21%
# openssl-1.1.1n       | 4.8 MB    | ##7        |  28%
# openssl-1.1.1n       | 4.8 MB    | ###5       |  35%
# openssl-1.1.1n       | 4.8 MB    | ####2      |  43%
# openssl-1.1.1n       | 4.8 MB    | #####      |  50%
# openssl-1.1.1n       | 4.8 MB    | #####7     |  57%
# openssl-1.1.1n       | 4.8 MB    | ######4    |  65%
# openssl-1.1.1n       | 4.8 MB    | #######1   |  72%
# openssl-1.1.1n       | 4.8 MB    | #######8   |  79%
# openssl-1.1.1n       | 4.8 MB    | ########6  |  87%
# openssl-1.1.1n       | 4.8 MB    | #########3 |  94%
# openssl-1.1.1n       | 4.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install -c intel mkl
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Dev\anaconda3\envs\GPU
#
#   added / updated specs:
#     - mkl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.3.18  |       haa95532_0         160 KB  intel
#     certifi-2021.10.8          |   py39haa95532_2         156 KB  intel
#     mkl-2021.4.0               |        intel_640       181.7 MB  intel
#     openssl-1.1.1n             |       h2bbff1b_0         5.8 MB  intel
#     tbb-2021.6.0               |   vc14_intel_834         217 KB  intel
#     ------------------------------------------------------------
#                                            Total:       187.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   tbb                intel/win-64::tbb-2021.6.0-vc14_intel_834
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.10.~ --> intel::ca-certificates-2022.3.18-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2021.10.8-py39hc~ --> intel::certifi-2021.10.8-py39haa95532_2
#   mkl                  pkgs/main::mkl-2021.4.0-haa95532_640 --> intel::mkl-2021.4.0-intel_640
#   openssl            conda-forge::openssl-1.1.1n-h8ffe710_0 --> intel::openssl-1.1.1n-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2021.10.8    | 156 KB    |            |   0%
# certifi-2021.10.8    | 156 KB    | #          |  10%
# certifi-2021.10.8    | 156 KB    | ###        |  31%
# certifi-2021.10.8    | 156 KB    | #######1   |  72%
# certifi-2021.10.8    | 156 KB    | ########## | 100%
#
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   0%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  |            |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   1%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 1          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   2%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 2          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   3%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 3          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
#
# Note: you may need to restart the kernel to use updated packages.mkl-2021.4.0         | 181.7 MB  | 4          |   4%
#
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   4%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 4          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   5%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 5          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   6%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 6          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   7%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 7          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   8%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 8          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |   9%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | 9          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  10%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #          |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  11%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #1         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  12%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #2         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  13%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #3         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  14%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #4         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  15%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #5         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  16%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #6         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  17%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #7         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  18%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #8         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  19%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | #9         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  20%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##         |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  21%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##1        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  22%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##2        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  23%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##3        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  24%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##4        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  25%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##5        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  26%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##6        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  27%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##7        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  28%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##8        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  29%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ##9        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  30%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###        |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  31%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###1       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  32%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###2       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  33%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###3       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  34%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###4       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  35%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###5       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  36%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###6       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  37%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  38%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  38%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  38%
# mkl-2021.4.0         | 181.7 MB  | ###7       |  38%
# ...
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  91%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########1 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  92%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########2 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  93%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########3 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  94%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########4 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  95%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########5 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  96%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########6 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  97%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########7 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  98%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########8 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 |  99%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | #########9 | 100%
# mkl-2021.4.0         | 181.7 MB  | ########## | 100%
#
# openssl-1.1.1n       | 5.8 MB    |            |   0%
# openssl-1.1.1n       | 5.8 MB    |            |   0%
# openssl-1.1.1n       | 5.8 MB    |            |   1%
# openssl-1.1.1n       | 5.8 MB    | 1          |   2%
# openssl-1.1.1n       | 5.8 MB    | 3          |   4%
# openssl-1.1.1n       | 5.8 MB    | 6          |   6%
# openssl-1.1.1n       | 5.8 MB    | 7          |   8%
# openssl-1.1.1n       | 5.8 MB    | 8          |   9%
# openssl-1.1.1n       | 5.8 MB    | #1         |  11%
# openssl-1.1.1n       | 5.8 MB    | #2         |  13%
# openssl-1.1.1n       | 5.8 MB    | #4         |  14%
# openssl-1.1.1n       | 5.8 MB    | #6         |  17%
# openssl-1.1.1n       | 5.8 MB    | #8         |  18%
# openssl-1.1.1n       | 5.8 MB    | #9         |  20%
# openssl-1.1.1n       | 5.8 MB    | ##1        |  22%
# openssl-1.1.1n       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1n       | 5.8 MB    | ##7        |  27%
# openssl-1.1.1n       | 5.8 MB    | ##8        |  28%
# openssl-1.1.1n       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1n       | 5.8 MB    | ###1       |  31%
# openssl-1.1.1n       | 5.8 MB    | ###2       |  32%
# openssl-1.1.1n       | 5.8 MB    | ###3       |  33%
# openssl-1.1.1n       | 5.8 MB    | ###4       |  35%
# openssl-1.1.1n       | 5.8 MB    | ###6       |  36%
# openssl-1.1.1n       | 5.8 MB    | ###7       |  38%
# openssl-1.1.1n       | 5.8 MB    | ###8       |  39%
# openssl-1.1.1n       | 5.8 MB    | ####       |  40%
# openssl-1.1.1n       | 5.8 MB    | ####1      |  41%
# openssl-1.1.1n       | 5.8 MB    | ####2      |  43%
# openssl-1.1.1n       | 5.8 MB    | ####3      |  44%
# openssl-1.1.1n       | 5.8 MB    | ####5      |  45%
# openssl-1.1.1n       | 5.8 MB    | ####6      |  46%
# openssl-1.1.1n       | 5.8 MB    | ####8      |  48%
# openssl-1.1.1n       | 5.8 MB    | ####9      |  49%
# openssl-1.1.1n       | 5.8 MB    | #####      |  50%
# openssl-1.1.1n       | 5.8 MB    | #####1     |  52%
# openssl-1.1.1n       | 5.8 MB    | #####3     |  53%
# openssl-1.1.1n       | 5.8 MB    | #####4     |  54%
# openssl-1.1.1n       | 5.8 MB    | #####6     |  56%
# openssl-1.1.1n       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1n       | 5.8 MB    | #####8     |  59%
# openssl-1.1.1n       | 5.8 MB    | ######     |  61%
# openssl-1.1.1n       | 5.8 MB    | ######2    |  62%
# openssl-1.1.1n       | 5.8 MB    | ######3    |  63%
# openssl-1.1.1n       | 5.8 MB    | ######4    |  65%
# openssl-1.1.1n       | 5.8 MB    | ######6    |  66%
# openssl-1.1.1n       | 5.8 MB    | ######7    |  68%
# openssl-1.1.1n       | 5.8 MB    | ######8    |  69%
# openssl-1.1.1n       | 5.8 MB    | ######9    |  70%
# openssl-1.1.1n       | 5.8 MB    | #######1   |  71%
# openssl-1.1.1n       | 5.8 MB    | #######2   |  72%
# openssl-1.1.1n       | 5.8 MB    | #######3   |  74%
# openssl-1.1.1n       | 5.8 MB    | #######4   |  75%
# openssl-1.1.1n       | 5.8 MB    | #######6   |  76%
# openssl-1.1.1n       | 5.8 MB    | #######7   |  78%
# openssl-1.1.1n       | 5.8 MB    | #######9   |  79%
# openssl-1.1.1n       | 5.8 MB    | ########   |  81%
# openssl-1.1.1n       | 5.8 MB    | ########1  |  82%
# openssl-1.1.1n       | 5.8 MB    | ########2  |  83%
# openssl-1.1.1n       | 5.8 MB    | ########4  |  84%
# openssl-1.1.1n       | 5.8 MB    | ########5  |  85%
# openssl-1.1.1n       | 5.8 MB    | ########6  |  87%
# openssl-1.1.1n       | 5.8 MB    | ########7  |  88%
# openssl-1.1.1n       | 5.8 MB    | ########9  |  89%
# openssl-1.1.1n       | 5.8 MB    | #########  |  90%
# openssl-1.1.1n       | 5.8 MB    | #########1 |  92%
# openssl-1.1.1n       | 5.8 MB    | #########3 |  93%
# openssl-1.1.1n       | 5.8 MB    | #########4 |  95%
# openssl-1.1.1n       | 5.8 MB    | #########6 |  96%
# openssl-1.1.1n       | 5.8 MB    | #########7 |  97%
# openssl-1.1.1n       | 5.8 MB    | #########8 |  99%
# openssl-1.1.1n       | 5.8 MB    | ########## | 100%
# openssl-1.1.1n       | 5.8 MB    | ########## | 100%
#
# tbb-2021.6.0         | 217 KB    |            |   0%
# tbb-2021.6.0         | 217 KB    | 7          |   7%
# tbb-2021.6.0         | 217 KB    | #######3   |  74%
# tbb-2021.6.0         | 217 KB    | ########## | 100%
#
# ca-certificates-2022 | 160 KB    |            |   0%
# ca-certificates-2022 | 160 KB    | #          |  10%
# ca-certificates-2022 | 160 KB    | ########## | 100%
# ca-certificates-2022 | 160 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !pip show mtcnn
# Out:
# Name: mtcnn
# Version: 0.1.1
# Summary: Multi-task Cascaded Convolutional Neural Networks for Face Detection, based on TensorFlow
# Home-page: http://github.com/ipazc/mtcnn
# Author: Iván de Paz Centeno
# Author-email: ipazc@unileon.es
# License: MIT
# Location: c:\users\dev\anaconda3\envs\gpu\lib\site-packages
# Requires: keras, opencv-python
# Required-by:
# Error processing line 1 of C:\Users\Dev\anaconda3\envs\GPU\lib\site-packages\matplotlib-3.5.2-py3.9-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Dev\anaconda3\envs\GPU\lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored

# %%
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.1.0

# %% [markdown]
# Download the images from the following link and place it in your current working directory with the filename test2.jpg & test1.jpg

# %% [markdown]
# https://machinelearningmastery.com/wp-content/uploads/2019/03/test2.jpg

# %% [markdown]
#  https://machinelearningmastery.com/wp-content/uploads/2019/03/test1.jpg

# %%
conda install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge zlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda cudatoolkit
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda cudatoolkit --force-reinstall

# %%
conda list cudatoolkit
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list cudnn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN
# load image from file
filename = 'test1.jpg'
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
for face in faces:
	print(face)
# Out:
# {'box': [373, 83, 100, 129], 'confidence': 0.9998095631599426, 'keypoints': {'left_eye': (392, 132), 'right_eye': (436, 139), 'nose': (403, 171), 'mouth_left': (390, 171), 'mouth_right': (438, 177)}}
# {'box': [185, 68, 91, 118], 'confidence': 0.9993304014205933, 'keypoints': {'left_eye': (208, 110), 'right_eye': (252, 119), 'nose': (220, 143), 'mouth_left': (200, 148), 'mouth_right': (245, 159)}}

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image
	pyplot.imshow(data)
	# get the context for drawing boxes
	ax = pyplot.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		# draw the box
		ax.add_patch(rect)
	# show the plot
	pyplot.show()

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
 
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image
	pyplot.imshow(data)
	# get the context for drawing boxes
	ax = pyplot.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		# draw the box
		ax.add_patch(rect)
	# show the plot
	pyplot.show()
 
filename = 'test1.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DE08311430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DE14324A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# You can draw a circle via the Circle class for the eyes, nose, and mouth.

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN
 
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot the image
	pyplot.imshow(data)
	# get the context for drawing boxes
	ax = pyplot.gca()
	# plot each box
	for result in result_list:
		# get coordinates
		x, y, width, height = result['box']
		# create the shape
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		# draw the box
		ax.add_patch(rect)
		# draw the dots
		for key, value in result['keypoints'].items():
			# create and draw dot
			dot = Circle(value, radius=2, color='red')
			ax.add_patch(dot)
	# show the plot
	pyplot.show()
 
filename = 'test1.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %% [markdown]
# You can now try face detection on the test2.jpg photograph.

# %% [markdown]
# You may want to extract the detected faces and pass them as input to another system. This can be achieved by extracting the pixel data directly out of the photograph; We can demonstrate this by extracting each face and plotting them as separate subplots. You could just as easily save them to file. The draw_faces() below extracts and plots each detected face in a photograph.

# %%
# extract and plot each detected face in a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN
 
# draw each face separately
def draw_faces(filename, result_list):
	# load the image
	data = pyplot.imread(filename)
	# plot each face as a subplot
	for i in range(len(result_list)):
		# get coordinates
		x1, y1, width, height = result_list[i]['box']
		x2, y2 = x1 + width, y1 + height
		# define subplot
		pyplot.subplot(1, len(result_list), i+1)
		pyplot.axis('off')
		# plot face
		pyplot.imshow(data[y1:y2, x1:x2])
	# show the plot
	pyplot.show()
 
filename = 'test2.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_faces(filename, faces)

# %% [markdown]
# Assignment 1: Detect faces from live images taken from webcam.
#
# Assignment 2: Once you're done with images, then take short live video sequence and detect faces.
#
# Assignment 3: Detect faces in mask wearing images.

# %%
# Ass1 - Detecting faces from live images taken from webcam

#libraries import
import cv2
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN


cam_port = 2
#cv2 lib's function to open the camera and start the live feed
cam = cv2.VideoCapture(cam_port)

result, image = cam.read()
if result:
    cv2.imshow("assign-1-image", image)
    def draw_image_with_boxes(filename, result_list):
        data = filename
        pyplot.imshow(data)
        ax = pyplot.gca()
        for result in result_list:
            x, y, width, height = result['box']
            rect = Rectangle((x, y), width, height, fill=False, color='red')
            ax.add_patch(rect)
            for key, value in result['keypoints'].items():
                dot = Circle(value, radius=2, color='red')
                ax.add_patch(dot)
        pyplot.show()
    pixels = image
    detector = MTCNN()

    #called inbuilt function detector and then function draw images vala cll krke, box banadiya
    faces = detector.detect_faces(pixels)
    draw_image_with_boxes(image, faces)
    cv2.waitKey(0)
else:
    print("No image detected. Please! try again")

# %%
# Ass2- Taking a short live video and detecting faces in it
import cv2  
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN

vid = cv2.VideoCapture(2)
  
while(True):
    ret, frame = vid.read()
    cv2.imshow('frame', frame)
    def draw_image_with_boxes(filename, result_list):
        data = filename
        pyplot.imshow(data)
        ax = pyplot.gca()
        for result in result_list:
            x, y, width, height = result['box']
            rect = Rectangle((x, y), width, height, fill=False, color='red')
            ax.add_patch(rect)
            for key, value in result['keypoints'].items():
                dot = Circle(value, radius=2, color='red')
                ax.add_patch(dot)
        pyplot.show()
    pixels = frame
    detector = MTCNN()
    faces = detector.detect_faces(pixels)
    draw_image_with_boxes(frame, faces)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
vid.release()
cv2.destroyAllWindows()

# %%
# Ass3 - Detecting faces in mask wearing images

from matplotlib import pyplot
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN
 
def draw_image_with_boxes(filename, result_list):
    data = pyplot.imread(filename)
    pyplot.imshow(data)
    ax = pyplot.gca()
    for result in result_list:
        x, y, width, height = result['box']
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        ax.add_patch(rect)
        for key, value in result['keypoints'].items():
            dot = Circle(value, radius=2, color='red')
            ax.add_patch(dot)
    pyplot.show()
 
filename = 'ananya_take2.jpg'
pixels = pyplot.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_image_with_boxes(filename, faces)
